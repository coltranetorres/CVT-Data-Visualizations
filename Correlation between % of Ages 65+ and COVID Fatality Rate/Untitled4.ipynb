# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('covid.xlsx', delimiter=',', index_col=2)
#columns_to_keep = data[['Fatality rate', 'gdp_per_capita', 'cvd_death_rate', 'diabetes_prevalence']]
#columns_to_keep.columns = ['Fatality Rate', 'GDP per Capita', 'COVID Death Rate', 'Diabetes Prevalence']
#columns_to_keep
#data = data[data['date']=='7/10/2020']
data
# Out:
#                iso_code      continent       date  total_cases  total_deaths  \
# location
# Argentina           ARG  South America 2020-07-10        90680          1707
# Australia           AUS        Oceania 2020-07-10         9059           106
# Austria             AUT         Europe 2020-07-10        18613           706
# Bahrain             BHR           Asia 2020-07-10        31528           103
# Bangladesh          BGD           Asia 2020-07-10       175494          2238
# Bulgaria            BGR         Europe 2020-07-10         6672           262
# Canada              CAN  North America 2020-07-10       106793          8749
# Chile               CHL  South America 2020-07-10       306216          6682
# Colombia            COL  South America 2020-07-10       133973          4714
# Cuba                CUB  North America 2020-07-10         2403            86
# Czech Republic      CZE         Europe 2020-07-10        12919           352
# ...

# %%
data['Fatality Rate'] = data['Unnamed: 6']
data1= data.drop(['Unnamed: 6'], axis=1)
data1
# Out:
#                iso_code      continent       date  total_cases  total_deaths  \
# location
# Argentina           ARG  South America 2020-07-10        90680          1707
# Australia           AUS        Oceania 2020-07-10         9059           106
# Austria             AUT         Europe 2020-07-10        18613           706
# Bahrain             BHR           Asia 2020-07-10        31528           103
# Bangladesh          BGD           Asia 2020-07-10       175494          2238
# Bulgaria            BGR         Europe 2020-07-10         6672           262
# Canada              CAN  North America 2020-07-10       106793          8749
# Chile               CHL  South America 2020-07-10       306216          6682
# Colombia            COL  South America 2020-07-10       133973          4714
# Cuba                CUB  North America 2020-07-10         2403            86
# Czech Republic      CZE         Europe 2020-07-10        12919           352
# ...

# %%
y_arg = data1['diabetes_prevalence'][0]
y_australia = data1['diabetes_prevalence'][1]
y_austria = data1['diabetes_prevalence'][2]
y_bah = data1['diabetes_prevalence'][3]
y_bang = data1['diabetes_prevalence'][4]
y_bul = data1['diabetes_prevalence'][5]
y_can = data1['diabetes_prevalence'][6]
y_chile = data1['diabetes_prevalence'][7]
y_col = data1['diabetes_prevalence'][8]
y_cuba = data1['diabetes_prevalence'][9]
y_cze = data1['diabetes_prevalence'][10]
y_den = data1['diabetes_prevalence'][11]
y_ecu = data1['diabetes_prevalence'][12]
y_elsa = data1['diabetes_prevalence'][13]
y_est = data1['diabetes_prevalence'][14]
y_fin = data1['diabetes_prevalence'][15]
y_gre = data1['diabetes_prevalence'][16]
y_hun = data1['diabetes_prevalence'][17]
y_india = data1['diabetes_prevalence'][18]
y_indo = data1['diabetes_prevalence'][19]
y_iran = data1['diabetes_prevalence'][20]
y_ire = data1['diabetes_prevalence'][21]
y_ita = data1['diabetes_prevalence'][22]
y_jap = data1['diabetes_prevalence'][23]
y_kaz = data1['diabetes_prevalence'][24]
y_ken = data1['diabetes_prevalence'][25]
y_kuw = data1['diabetes_prevalence'][26]
y_latv = data1['diabetes_prevalence'][27]
y_lith = data1['diabetes_prevalence'][28]
y_lux = data1['diabetes_prevalence'][29]
y_mal = data1['diabetes_prevalence'][30]
y_mor = data1['diabetes_prevalence'][31]
y_nz = data1['diabetes_prevalence'][32]
y_nig = data1['diabetes_prevalence'][33]
y_nor = data1['diabetes_prevalence'][34]
y_pak = data1['diabetes_prevalence'][35]
y_pan = data1['diabetes_prevalence'][36]
y_peru = data1['diabetes_prevalence'][37]
y_pol = data1['diabetes_prevalence'][38]
y_qat = data1['diabetes_prevalence'][39]
y_roman = data1['diabetes_prevalence'][40]
y_rus = data1['diabetes_prevalence'][41]
y_rwa = data1['diabetes_prevalence'][42]
y_sau = data1['diabetes_prevalence'][43]
y_serb = data1['diabetes_prevalence'][44]
y_slova = data1['diabetes_prevalence'][45]
y_slove = data1['diabetes_prevalence'][46]
y_saf = data1['diabetes_prevalence'][47]
y_skor = data1['diabetes_prevalence'][48]
y_switz = data1['diabetes_prevalence'][49]
y_turk = data1['diabetes_prevalence'][50]
y_uga = data1['diabetes_prevalence'][51]
y_ukr = data1['diabetes_prevalence'][52]
y_uk = data1['diabetes_prevalence'][53]
y_us = data1['diabetes_prevalence'][54]

x_arg = data1['Fatality Rate'][0]
x_australia = data1['Fatality Rate'][1]
x_austria = data1['Fatality Rate'][2]
x_bah = data1['Fatality Rate'][3]
x_bang = data1['Fatality Rate'][4]
x_bul = data1['Fatality Rate'][5]
x_can = data1['Fatality Rate'][6]
x_chile = data1['Fatality Rate'][7]
x_col = data1['Fatality Rate'][8]
x_cuba = data1['Fatality Rate'][9]
x_cze = data1['Fatality Rate'][10]
x_den = data1['Fatality Rate'][11]
x_ecu = data1['Fatality Rate'][12]
x_elsa = data1['Fatality Rate'][13]
x_est = data1['Fatality Rate'][14]
x_fin = data1['Fatality Rate'][15]
x_gre = data1['Fatality Rate'][16]
x_hun = data1['Fatality Rate'][17]
x_india = data1['Fatality Rate'][18]
x_indo = data1['Fatality Rate'][19]
x_iran = data1['Fatality Rate'][20]
x_ire = data1['Fatality Rate'][21]
x_ita = data1['Fatality Rate'][22]
x_jap = data1['Fatality Rate'][23]
x_kaz = data1['Fatality Rate'][24]
x_ken = data1['Fatality Rate'][25]
x_kuw = data1['Fatality Rate'][26]
x_latv = data1['Fatality Rate'][27]
x_lith = data1['Fatality Rate'][28]
x_lux = data1['Fatality Rate'][29]
x_mal = data1['Fatality Rate'][30]
x_mor = data1['Fatality Rate'][31]
x_nz = data1['Fatality Rate'][32]
x_nig = data1['Fatality Rate'][33]
x_nor = data1['Fatality Rate'][34]
x_pak = data1['Fatality Rate'][35]
x_pan = data1['Fatality Rate'][36]
x_peru = data1['Fatality Rate'][37]
x_pol = data1['Fatality Rate'][38]
x_qat = data1['Fatality Rate'][39]
x_roman = data1['Fatality Rate'][40]
x_rus = data1['Fatality Rate'][41]
x_rwa = data1['Fatality Rate'][42]
x_sau = data1['Fatality Rate'][43]
x_serb = data1['Fatality Rate'][44]
x_slova = data1['Fatality Rate'][45]
x_slove = data1['Fatality Rate'][46]
x_saf = data1['Fatality Rate'][47]
x_skor = data1['Fatality Rate'][48]
x_switz = data1['Fatality Rate'][49]
x_turk = data1['Fatality Rate'][50]
x_uga = data1['Fatality Rate'][51]
x_ukr = data1['Fatality Rate'][52]
x_uk = data1['Fatality Rate'][53]
x_us = data1['Fatality Rate'][54]

# %%
data2 = {'Diabetes Prevalence':[y_arg, y_australia, y_austria, y_bah, y_bang, y_bul, y_can, y_chile,
                y_col, y_cuba, y_cze, y_den, y_ecu, y_elsa, y_est, y_fin, y_gre, y_hun, y_india, y_indo, y_iran, y_ire, y_ita, y_jap,
                y_kaz, y_ken, y_kuw, y_latv, y_lith, y_lux, y_mal, y_mor, y_nz, y_nig, y_nor, y_pak, y_pan, y_peru, y_pol,
                y_qat, y_roman, y_rus, y_rwa, y_sau, y_serb, y_slova, y_slove, y_saf, y_skor, y_switz, y_turk, y_uga, y_ukr,
                y_uk, y_us], 'COVID Fatality Rate':[x_arg, x_australia, x_austria, x_bah, x_bang, x_bul, x_can, x_chile, x_col,
                x_cuba, x_cze, x_den, x_ecu, x_elsa, x_est, x_fin, x_gre, x_hun, x_india, x_indo, x_iran, x_ire, x_ita, x_jap, x_kaz,
                x_ken, x_kuw, x_latv, x_lith, x_lux, x_mal, x_mor, x_nz, x_nig, x_nor, x_pak, x_pan, x_peru, x_pol, x_qat,
                x_roman, x_rus, x_rwa, x_sau, x_serb, x_slova, x_slove, x_saf, x_skor, x_switz, x_turk, x_uga, x_ukr, x_uk, 
                x_us], 'Country':['Argentina', 'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Bulgaria', 'Canada', 'Chile', 'Colombia',
                'Cuba', 'Czech Republic', 'Denver', 'Ecuador', 'El Salvador', 'Estonia', 'Finland', 'Greece', 'Hungary',
                'India', 'Indonesia', 'Iran', 'Ireland', 'Italy', 'Japan', 'Kazakhstan', 'Kenya', 'Kuwait', 'Latvia', 'Lithuania',
                'Luxembourg', 'Malaysia', 'Morocco', 'New Zealand', 'Nigeria', 'Norway', 'Pakistan', 'Panama', 'Peru', 'Poland',
                'Qatar', 'Romania', 'Russia', 'Rwanda', 'Saudi Arabia', 'Serbia', 'Slovakia', 'Slovenia', 'South Africa',
                'South Korea', 'Switzerland', 'Turkey', 'Uganda', 'Ukraine', 'United Kingdom', 'United States'
                ], }

# Create DataFrame 
df = pd.DataFrame(data2) 
  
# Print the output. 
df.fillna(0)
# Out:
#     Diabetes Prevalence  COVID Fatality Rate         Country
# 0                  5.50             0.018824       Argentina
# 1                  5.07             0.011701       Australia
# 2                  6.35             0.037930         Austria
# 3                 16.52             0.003267         Bahrain
# 4                  8.38             0.012753      Bangladesh
# 5                  5.81             0.039269        Bulgaria
# 6                  7.37             0.081925          Canada
# 7                  8.46             0.021821           Chile
# 8                  7.44             0.035186        Colombia
# 9                  8.27             0.035789            Cuba
# 10                 6.82             0.027247  Czech Republic
# 11                 6.41             0.047151          Denver
# 12                 5.55             0.075964         Ecuador
# 13                 8.87             0.027476     El Salvador
# ...

# %%
import matplotlib as mpl
#df.plot.scatter(x='Diabetes Prevalence', y='Fatality Rate', 
#                title='Diabetes Prevalence vs. Fatality Rate', color='r');
ax = df.plot(kind='scatter',x='Diabetes Prevalence',y='COVID Fatality Rate', title='Correlation between Diabetes Prevalence and COVID Fatality Rate', color='r')
df[['Diabetes Prevalence','COVID Fatality Rate','Country']].apply(lambda row: ax.text(*row),axis=1);
#ax.grid(linestyle='-', linewidth='0.5', color='black')
#plt.gca().set_aspect("equal")
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 10
plt.rcParams['grid.color'] = "#000000"
plt.grid(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.gcf().set_size_inches((10, 10)) 
plt.rcParams.update({'font.size': 12.5})
#plt.savefig('diabetes.png', dpi=300)

# %%
import pandas as pd

df = pd.read_csv('2019-Annual.csv')
df
# Out:
#        Edition  Report Type                   Measure Name     State Name  \
# 0         2019  2019 Annual  Adverse Childhood Experiences         Alaska
# 1         2019  2019 Annual  Adverse Childhood Experiences        Alabama
# 2         2019  2019 Annual  Adverse Childhood Experiences  United States
# 3         2019  2019 Annual  Adverse Childhood Experiences       Arkansas
# 4         2019  2019 Annual  Adverse Childhood Experiences        Arizona
# ...        ...          ...                            ...            ...
# 56921     2019  2019 Annual             Water Fluoridation        Vermont
# 56922     2019  2019 Annual             Water Fluoridation     Washington
# 56923     2019  2019 Annual             Water Fluoridation      Wisconsin
# 56924     2019  2019 Annual             Water Fluoridation  West Virginia
# 56925     2019  2019 Annual             Water Fluoridation        Wyoming
#
#        Rank  Value  Score  Lower CI  Upper CI  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('covid.xlsx', delimiter=',', index_col=2)
#columns_to_keep = data[['Fatality rate', 'gdp_per_capita', 'cvd_death_rate', 'diabetes_prevalence']]
#columns_to_keep.columns = ['Fatality Rate', 'GDP per Capita', 'COVID Death Rate', 'Diabetes Prevalence']
#columns_to_keep
data = data[data['date']=='7/10/2020']
data
# Out:
#                iso_code      continent       date  total_cases  total_deaths  \
# location
# Argentina           ARG  South America 2020-07-10        90680          1707
# Australia           AUS        Oceania 2020-07-10         9059           106
# Austria             AUT         Europe 2020-07-10        18613           706
# Bahrain             BHR           Asia 2020-07-10        31528           103
# Bangladesh          BGD           Asia 2020-07-10       175494          2238
# Bulgaria            BGR         Europe 2020-07-10         6672           262
# Canada              CAN  North America 2020-07-10       106793          8749
# Chile               CHL  South America 2020-07-10       306216          6682
# Colombia            COL  South America 2020-07-10       133973          4714
# Cuba                CUB  North America 2020-07-10         2403            86
# Czech Republic      CZE         Europe 2020-07-10        12919           352
# ...

# %%
data['Fatality Rate'] = data['Unnamed: 6']
data1= data.drop(['Unnamed: 6'], axis=1)
data1
# Out:
#                iso_code      continent       date  total_cases  total_deaths  \
# location
# Argentina           ARG  South America 2020-07-10        90680          1707
# Australia           AUS        Oceania 2020-07-10         9059           106
# Austria             AUT         Europe 2020-07-10        18613           706
# Bahrain             BHR           Asia 2020-07-10        31528           103
# Bangladesh          BGD           Asia 2020-07-10       175494          2238
# Bulgaria            BGR         Europe 2020-07-10         6672           262
# Canada              CAN  North America 2020-07-10       106793          8749
# Chile               CHL  South America 2020-07-10       306216          6682
# Colombia            COL  South America 2020-07-10       133973          4714
# Cuba                CUB  North America 2020-07-10         2403            86
# Czech Republic      CZE         Europe 2020-07-10        12919           352
# ...

# %%
y_arg = data1['aged_65_older'][0]
y_australia = data1['aged_65_older'][1]
y_austria = data1['aged_65_older'][2]
y_bah = data1['aged_65_older'][3]
y_bang = data1['aged_65_older'][4]
y_bul = data1['aged_65_older'][5]
y_can = data1['aged_65_older'][6]
y_chile = data1['aged_65_older'][7]
y_col = data1['aged_65_older'][8]
y_cuba = data1['aged_65_older'][9]
y_cze = data1['aged_65_older'][10]
y_den = data1['aged_65_older'][11]
y_ecu = data1['aged_65_older'][12]
y_elsa = data1['aged_65_older'][13]
y_est = data1['aged_65_older'][14]
y_fin = data1['aged_65_older'][15]
y_gre = data1['aged_65_older'][16]
y_hun = data1['aged_65_older'][17]
y_india = data1['aged_65_older'][18]
y_indo = data1['aged_65_older'][19]
y_iran = data1['aged_65_older'][20]
y_ire = data1['aged_65_older'][21]
y_ita = data1['aged_65_older'][22]
y_jap = data1['aged_65_older'][23]
y_kaz = data1['aged_65_older'][24]
y_ken = data1['aged_65_older'][25]
y_kuw = data1['aged_65_older'][26]
y_latv = data1['aged_65_older'][27]
y_lith = data1['aged_65_older'][28]
y_lux = data1['aged_65_older'][29]
y_mal = data1['aged_65_older'][30]
y_mor = data1['aged_65_older'][31]
y_nz = data1['aged_65_older'][32]
y_nig = data1['aged_65_older'][33]
y_nor = data1['aged_65_older'][34]
y_pak = data1['aged_65_older'][35]
y_pan = data1['aged_65_older'][36]
y_peru = data1['aged_65_older'][37]
y_pol = data1['aged_65_older'][38]
y_qat = data1['aged_65_older'][39]
y_roman = data1['aged_65_older'][40]
y_rus = data1['aged_65_older'][41]
y_rwa = data1['aged_65_older'][42]
y_sau = data1['aged_65_older'][43]
y_serb = data1['aged_65_older'][44]
y_slova = data1['aged_65_older'][45]
y_slove = data1['aged_65_older'][46]
y_saf = data1['aged_65_older'][47]
y_skor = data1['aged_65_older'][48]
y_switz = data1['aged_65_older'][49]
y_turk = data1['aged_65_older'][50]
y_uga = data1['aged_65_older'][51]
y_ukr = data1['aged_65_older'][52]
y_uk = data1['aged_65_older'][53]
y_us = data1['aged_65_older'][54]

x_arg = data1['Fatality Rate'][0]
x_australia = data1['Fatality Rate'][1]
x_austria = data1['Fatality Rate'][2]
x_bah = data1['Fatality Rate'][3]
x_bang = data1['Fatality Rate'][4]
x_bul = data1['Fatality Rate'][5]
x_can = data1['Fatality Rate'][6]
x_chile = data1['Fatality Rate'][7]
x_col = data1['Fatality Rate'][8]
x_cuba = data1['Fatality Rate'][9]
x_cze = data1['Fatality Rate'][10]
x_den = data1['Fatality Rate'][11]
x_ecu = data1['Fatality Rate'][12]
x_elsa = data1['Fatality Rate'][13]
x_est = data1['Fatality Rate'][14]
x_fin = data1['Fatality Rate'][15]
x_gre = data1['Fatality Rate'][16]
x_hun = data1['Fatality Rate'][17]
x_india = data1['Fatality Rate'][18]
x_indo = data1['Fatality Rate'][19]
x_iran = data1['Fatality Rate'][20]
x_ire = data1['Fatality Rate'][21]
x_ita = data1['Fatality Rate'][22]
x_jap = data1['Fatality Rate'][23]
x_kaz = data1['Fatality Rate'][24]
x_ken = data1['Fatality Rate'][25]
x_kuw = data1['Fatality Rate'][26]
x_latv = data1['Fatality Rate'][27]
x_lith = data1['Fatality Rate'][28]
x_lux = data1['Fatality Rate'][29]
x_mal = data1['Fatality Rate'][30]
x_mor = data1['Fatality Rate'][31]
x_nz = data1['Fatality Rate'][32]
x_nig = data1['Fatality Rate'][33]
x_nor = data1['Fatality Rate'][34]
x_pak = data1['Fatality Rate'][35]
x_pan = data1['Fatality Rate'][36]
x_peru = data1['Fatality Rate'][37]
x_pol = data1['Fatality Rate'][38]
x_qat = data1['Fatality Rate'][39]
x_roman = data1['Fatality Rate'][40]
x_rus = data1['Fatality Rate'][41]
x_rwa = data1['Fatality Rate'][42]
x_sau = data1['Fatality Rate'][43]
x_serb = data1['Fatality Rate'][44]
x_slova = data1['Fatality Rate'][45]
x_slove = data1['Fatality Rate'][46]
x_saf = data1['Fatality Rate'][47]
x_skor = data1['Fatality Rate'][48]
x_switz = data1['Fatality Rate'][49]
x_turk = data1['Fatality Rate'][50]
x_uga = data1['Fatality Rate'][51]
x_ukr = data1['Fatality Rate'][52]
x_uk = data1['Fatality Rate'][53]
x_us = data1['Fatality Rate'][54]

# %%
data2 = {'% of Ages 65+':[y_arg, y_australia, y_austria, y_bah, y_bang, y_bul, y_can, y_chile,
                y_col, y_cuba, y_cze, y_den, y_ecu, y_elsa, y_est, y_fin, y_gre, y_hun, y_india, y_indo, y_iran, y_ire, y_ita, y_jap,
                y_kaz, y_ken, y_kuw, y_latv, y_lith, y_lux, y_mal, y_mor, y_nz, y_nig, y_nor, y_pak, y_pan, y_peru, y_pol,
                y_qat, y_roman, y_rus, y_rwa, y_sau, y_serb, y_slova, y_slove, y_saf, y_skor, y_switz, y_turk, y_uga, y_ukr,
                y_uk, y_us], 'COVID Fatality Rate':[x_arg, x_australia, x_austria, x_bah, x_bang, x_bul, x_can, x_chile, x_col,
                x_cuba, x_cze, x_den, x_ecu, x_elsa, x_est, x_fin, x_gre, x_hun, x_india, x_indo, x_iran, x_ire, x_ita, x_jap, x_kaz,
                x_ken, x_kuw, x_latv, x_lith, x_lux, x_mal, x_mor, x_nz, x_nig, x_nor, x_pak, x_pan, x_peru, x_pol, x_qat,
                x_roman, x_rus, x_rwa, x_sau, x_serb, x_slova, x_slove, x_saf, x_skor, x_switz, x_turk, x_uga, x_ukr, x_uk, 
                x_us], 'Country':['Argentina', 'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Bulgaria', 'Canada', 'Chile', 'Colombia',
                'Cuba', 'Czech Republic', 'Denmark', 'Ecuador', 'El Salvador', 'Estonia', 'Finland', 'Greece', 'Hungary',
                'India', 'Indonesia', 'Iran', 'Ireland', 'Italy', 'Japan', 'Kazakhstan', 'Kenya', 'Kuwait', 'Latvia', 'Lithuania',
                'Luxembourg', 'Malaysia', 'Morocco', 'New Zealand', 'Nigeria', 'Norway', 'Pakistan', 'Panama', 'Peru', 'Poland',
                'Qatar', 'Romania', 'Russia', 'Rwanda', 'Saudi Arabia', 'Serbia', 'Slovakia', 'Slovenia', 'South Africa',
                'South Korea', 'Switzerland', 'Turkey', 'Uganda', 'Ukraine', 'United Kingdom', 'United States'
                ], }

# Create DataFrame 
df = pd.DataFrame(data2) 
  
# Print the output. 
#df.fillna(0).drop(['Country'], axis=1)
#waq = df['% of Ages 65+']
#waq
try1 = df.fillna(0).drop(['Country'], axis = 1).values.tolist()
try1
# Out:
# [[11.198, 0.018824437582708426],
#  [15.504, 0.01170107075836185],
#  [19.202, 0.037930478697684414],
#  [2.372, 0.0032669373255518903],
#  [5.098, 0.012752572737529487],
#  [20.801, 0.03926858513189448],
#  [16.984, 0.08192484526139354],
#  [11.087, 0.021821198108524703],
#  [7.646, 0.035186194233166386],
#  [14.738, 0.0357885975863504],
#  [19.027, 0.027246690920349873],
#  [19.677, 0.04715082068751936],
#  [7.104, 0.07596357931649697],
#  [8.273, 0.027476255088195387],
#  [19.452, 0.034311287916459474],
#  [21.228, 0.04523580365736285],
#  [20.396, 0.0525599128540305],
#  [18.577, 0.1400473933649289],
#  [5.989, 0.027215854835336773],
#  [5.319, 0.048306378647364846],
#  [5.44, 0.049129993851264486],
#  [13.928, 0.06817915118325836],
#  [23.021, 0.14410615481736075],
#  [27.049, 0.048156693338569534],
#  [6.991, 0.004822182037371911],
#  [2.686, 0.019275766016713092],
#  [2.345, 0.007229371688115064],
#  [19.754, 0.025996533795493933],
#  [19.002, 0.04254173397953689],
# ...

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage,AnnotationBbox

ax = df.plot(kind='scatter',x='% of Ages 65+',y='COVID Fatality Rate', title='Correlation between % of Ages 65+ and COVID Fatality Rate', color='r')
df[['% of Ages 65+','COVID Fatality Rate','Country']].apply(lambda row: ax.text(*row),axis=1);
ax.grid(linestyle='-', linewidth='0.5', color='black')
plt.gcf().set_size_inches((20, 10)) 
plt.rcParams.update({'font.size': 12.5})
plt.xticks(np.arange(0, 45, 2)) 
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 10
plt.rcParams['grid.color'] = "#000000"
plt.grid(True)

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import itertools

def get_flag(name):
    path = "flags/flags/{}.png".format(name)
    im = plt.imread(path)
    return im     
    
def offset_image(name, xy, ax):
    
    #xcor = (x_arg, x_australia, x_austria, x_bah, x_bang, x_bul, x_can, x_chile, x_col, x_cuba, x_cze, x_den,
    #            x_ecu, x_elsa, x_est, x_fin, x_gre, x_hun, x_india, x_indo, x_iran, x_ire, x_ita, x_jap, x_kaz, x_ken,
    #            x_kuw, x_latv, x_lith, x_lux, x_mal, x_mor, x_nz, x_nig, x_nor, x_pak, x_pan, x_peru, x_pol, x_qat, x_roman,
    #            x_rus, x_rwa, x_sau, x_serb, x_slova, x_slove, x_saf, x_skor, x_switz, x_turk, x_uga, x_ukr, x_uk, x_us)
    
    #ycor = (y_arg, y_australia, y_austria, y_bah, y_bang, y_bul, y_can, y_chile, y_col, y_cuba, y_cze, y_den,
    #            y_ecu, y_elsa, y_est, y_fin, y_gre, y_hun, y_india, y_indo, y_iran, y_ire, y_ita, y_jap, y_kaz, y_ken,
    #            y_kuw, y_latv, y_lith, y_lux, y_mal, y_mor, y_nz, y_nig, y_nor, y_pak, y_pan, y_peru, y_pol, y_qat, y_roman,
    #            y_rus, y_rwa, y_sau, y_serb, y_slova, y_slove, y_saf, y_skor, y_switz, y_turk, y_uga, y_ukr, y_uk, y_us)

    #xy = try1
    #xy = (xcor, ycor)
    #print(type(xy))
    #x_val = [x[0] for x in xy]
    #y_val = [x[1] for x in xy]
    #print(xy)
    xy = np.array([
    [x_arg, y_arg], [x_australia, y_australia], [x_austria, y_austria], [x_bah, y_bah], [x_bang, y_bang], [x_bul, y_bul],
    [x_can, y_can], [x_chile, y_chile], [x_col, y_col], [x_cuba, y_cuba], [x_cze, y_cze], [x_den, y_den], [x_ecu, y_ecu],
    [x_elsa, y_elsa], [x_est, y_est], [x_fin, y_fin], [x_gre, y_gre], [x_hun, y_hun], [x_india, y_india], [x_indo, y_indo],
    [x_iran, y_iran], [x_ire, y_ire], [x_ita, y_ita], [x_jap, y_jap], [x_kaz, y_kaz], [x_ken, y_ken], [x_kuw, y_kuw],
    [x_latv, y_latv], [x_lith, y_lith], [x_lux, y_lux], [x_mal, y_mal], [x_mor, y_mor], [x_nz, y_nz], [x_nig, y_nig],
    [x_nor, y_nor], [x_pak, y_pak], [x_pan, y_pan], [x_peru, y_peru], [x_pol, y_pol], [x_qat, y_qat], [x_roman, y_roman],
    [x_rus, y_rus], [x_rwa, y_rwa], [x_sau, y_sau], [x_serb, y_serb], [x_slova, y_slova], [x_slove, y_slove], [x_saf, y_saf],
    [x_skor, y_skor], [x_switz, y_switz], [x_turk, y_turk], [x_uga, y_uga], [x_ukr, y_ukr], [x_uk, y_uk], [x_us, y_us],
    ])
    x, y = xy.T
    #final_xy = (x,y)
    #final_xy = np.concatenate(x, y)
    #print(final_xy)
    #xcoor = x.reshape(-1,1)
    #ycoor = y.reshape(-1,1)
    #final_xy = np.vectorize(np.concatenate((xcoor,ycoor),axis = 1))
    #print(final_xy)
    #print(final_xy)
    #final = xy.dtype(float64)
    coordList = []
    for row in xy:
        #lat = row[y]             # Y coordinate
        #lon = row[x]             # X coordinate
        lats = xy[0:,1].astype(int)
        lons = xy[0:,0].astype(int)
        coordList.append([lats,lons])
    #final_xy = coordList.append([lats,lons]) 
    #print(coordList)
    #print(xy[0:,1])
    #print(xy[0:,0])
    #print(xy)
    #print(xy[1:,1])
    #finaler = final_xy.astype(int)
    #print(finaler)
    #print(finaler)
    #finaler = zip(*final_xy)
    #print(finaler)
    #print(final_xy)
    #plt.scatter(xcor,ycor)
    #final_xy = (xcor,ycor)
        
    #final_xy = [int(x) for x in xy.split(',')]
    #print(final_xy)
    #xy=(xcor,ycor)
    #print(xy)
    #final_xy = [int(x) for x in xy.split(',')]
     

    
    img = get_flag(name)
    im = OffsetImage(img, zoom=0.72)
    im.image.axes = ax
    
    ab = AnnotationBbox(im, final_xy, frameon=False, xycoords='data', boxcoords="offset points", pad=0)
    
    ax.add_artist(ab)
    
    #print(type(xy))
    #test = xy
    #res = type(test) is tuple
    #print("Is variable tuple ? : " + str(res)) 
    
#fig, ax = plt.subplots()
    
#ax.plot(kind='scatter', x='xcor', y='ycor')
#ax.scatter(xcor, ycor)
#plt.show()
#offset_image(name, ax, xy)
ax = df.plot(kind='scatter',x='% of Ages 65+',y='COVID Fatality Rate', title='Correlation between % of Ages 65+ and COVID Fatality Rate')

for i, c in enumerate(df['Country']):
    offset_image(i, c, ax)

plt.show()

#print(len(xy))
#wa = df['% of Ages 65+']
#aw = df['COVID Fatality Rate']
#def awd(wa, aw):
#    return wa, aw

#print(awd(wa, aw))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-cafc57832b57> in <module>
#      99
#     100 for i, c in enumerate(df['Country']):
# --> 101     offset_image(i, c, ax)
#     102
#     103 plt.show()
#
# <ipython-input-12-cafc57832b57> in offset_image(name, xy, ax)
#      77
#      78
# ---> 79     img = get_flag(name)
#      80     im = OffsetImage(img, zoom=0.72)
#      81     im.image.axes = ax
#
# <ipython-input-12-cafc57832b57> in get_flag(name)
#       6 def get_flag(name):
#       7     path = "flags/flags/{}.png".format(name)
# ----> 8     im = plt.imread(path)
#       9     return im
#      10
#
# c:\users\ctc219-pc01\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2059 @docstring.copy(matplotlib.image.imread)
#    2060 def imread(fname, format=None):
# ...

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage,AnnotationBbox

def get_flag(name):
    path = "flags/flags/{}.png".format(name.title())
    im = plt.imread(path)
    return im

def offset_image(coord, name, ax):
    
    img = get_flag(name)
    im = OffsetImage(img, zoom=0.72)
    im.image.axes = ax

    ab = AnnotationBbox(im, (coord, 0),  xybox=(0., -16.), frameon=False,
                        xycoords='data',  boxcoords="offset points", pad=0)

    ax.add_artist(ab)
    
y_axis = [y_arg, y_australia, y_austria, y_bah, y_bang, y_bul, y_can, y_chile, y_col, y_cuba, y_cze, y_den,
         y_ecu, y_elsa, y_est, y_fin, y_gre, y_hun, y_india, y_indo, y_iran, y_ire, y_ita, y_jap, y_kaz, y_ken,
         y_kuw, y_latv, y_lith, y_lux, y_mal, y_mor, y_nz, y_nig, y_nor, y_pak, y_pan, y_peru, y_pol, y_qat, y_roman,
         y_rus, y_rwa, y_sau, y_serb, y_slova, y_slove, y_saf, y_skor, y_switz, y_turk, y_uga, y_ukr, y_uk, y_us]
x_axis = ['Argentina', 'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Bulgaria', 'Canada', 'Chile',
         'Colombia', 'Cuba', 'Czech Republic', 'Denmark', 'Ecuador', 'El Salvador', 'Estonia', 'Finland', 'Greece', 
         'Hungary', 'India', 'Indonesia', 'Iran', 'Ireland', 'Italy', 'Japan', 'Kazakhstan', 'Kenya', 'Kuwait', 'Latvia',
         'Lithuania', 'Luxembourg','Malaysia', 'Morocco', 'New Zealand', 'Nigeria', 'Norway', 'Pakistan', 'Panama', 'Peru', 'Poland',
         'Qatar', 'Romania', 'Russia', 'Rwanda', 'Saudi Arabia', 'Serbia', 'Slovakia', 'Slovenia', 'South Africa',
         'South Korea', 'Switzerland', 'Turkey', 'Uganda', 'Ukraine', 'United Kingdom', 'United States']

#print(y_axis, x_axis)

fig, ax = plt.subplots(figsize=(30,5))

ax.bar(range(len(x_axis)), y_axis, width=0.5,align="center", color='r')
ax.set_title('% of Ages 65+ of Countries')
ax.set_xticks(range(len(x_axis)))
ax.set_xticklabels(x_axis)
plt.xticks(rotation=45)
plt.ylabel('% of Ages 65+')
ax.tick_params(axis='x', which='major', pad=26)
plt.savefig('bar.png', dpi=300)

for i, c in enumerate(x_axis):
    offset_image(i, c, ax)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

def getImage(path):
    return OffsetImage(plt.imread(path))

paths = [
    'Argentina.png', 'Australia.png', 'Austria.png', 'Bahrain.png', 'Bangladesh.png', 'Bulgaria.png', 'Canada.png', 'Chile.png',
    'Colombia.png', 'Cuba.png', 'Czech Republic.png', 'Denmark.png', 'Ecuador.png', 'El Salvador.png', 'Estonia.png',
    'Finland.png', 'Greece.png', 'Hungary.png', 'India.png', 'Indonesia.png', 'Iran.png', 'Ireland.png', 'Italy.png', 'Japan.png', 
    'Kazakhstan.png', 'Kenya.png', 'Kuwait.png', 'Latvia.png', 'Lithuania.png', 'Luxembourg.png','Malaysia.png', 
    'Morocco.png', 'New Zealand.png', 'Nigeria.png', 'Norway.png', 'Pakistan.png', 'Panama.png', 'Peru.png', 'Poland.png', 
    'Qatar.png', 'Romania.png', 'Russia.png', 'Rwanda.png', 'Saudi Arabia.png', 'Serbia.png', 
    'Slovakia.png', 'Slovenia.png', 'South Africa.png','South Korea.png', 'Switzerland.png', 'Turkey.png', 
    'Uganda.png', 'Ukraine.png', 'United Kingdom.png', 'United States.png']

x = [y_arg, y_australia, y_austria, y_bah, y_bang, y_bul, y_can, y_chile,
    y_col, y_cuba, y_cze, y_den, y_ecu, y_elsa, y_est, y_fin, y_gre, y_hun, y_india, y_indo, y_iran, y_ire, y_ita, y_jap,
    y_kaz, y_ken, y_kuw, y_latv, y_lith, y_lux, y_mal, y_mor, y_nz, y_nig, y_nor, y_pak, y_pan, y_peru, y_pol,
    y_qat, y_roman, y_rus, y_rwa, y_sau, y_serb, y_slova, y_slove, y_saf, y_skor, y_switz, y_turk, y_uga, y_ukr,
    y_uk, y_us]
y = [x_arg, x_australia, x_austria, x_bah, x_bang, x_bul, x_can, x_chile, x_col,
    x_cuba, x_cze, x_den, x_ecu, x_elsa, x_est, x_fin, x_gre, x_hun, x_india, x_indo, x_iran, x_ire, x_ita, x_jap, x_kaz,
    x_ken, x_kuw, x_latv, x_lith, x_lux, x_mal, x_mor, x_nz, x_nig, x_nor, x_pak, x_pan, x_peru, x_pol, x_qat,
    x_roman, x_rus, x_rwa, x_sau, x_serb, x_slova, x_slove, x_saf, x_skor, x_switz, x_turk, x_uga, x_ukr, x_uk, 
    x_us]

fig, ax = plt.subplots()
ax.scatter(x, y) 
ax.grid(linestyle='-', linewidth='0.5', color='black')
ax.set_title('Correlation between % of Ages 65+ and COVID Fatality Rate')
plt.xlabel('% of Ages 65+')
plt.ylabel('COVID Fatality Rate')
plt.gcf().set_size_inches((20, 10)) 
plt.rcParams.update({'font.size': 12.5})
plt.xticks(np.arange(0, 45, 2)) 
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 10
plt.rcParams['grid.color'] = "#000000"
plt.grid(True)
plt.savefig('flags.png', dpi=300)

for x0, y0, path in zip(x, y,paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
    ax.add_artist(ab)
